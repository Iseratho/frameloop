# %%
import pandas as pd

# %%
df_h = pd.read_csv("/kaggle/input/mind-label-seq-gen/framelabel_history.txt", header=None)
df_h[0].str.split().map(len).describe()
# Out:
# count    49108.000000
# mean        18.857579
# std         23.984882
# min          1.000000
# 25%          6.000000
# 50%         11.000000
# 75%         23.000000
# max        558.000000
# Name: 0, dtype: float64

# %%
df_pc = pd.read_csv("/kaggle/input/mind-label-seq-gen/framelabel_history_per_category.txt", header=None)
df_pc[0].str.split().map(len).describe()
# Out:
# count    687054.000000
# mean          6.836578
# std           9.815729
# min           2.000000
# 25%           2.000000
# 50%           4.000000
# 75%           7.000000
# max         256.000000
# Name: 0, dtype: float64

# %%
pd.options.display.float_format = '{:.6f}'.format
df_pc = pd.read_csv("/kaggle/input/mind-label-seq-gen/framelabel_seen.txt", header=None)
df_pc[0].str.split().map(len).describe()
# Out:
# count   5723002.000000
# mean         37.258116
# std          43.104689
# min           2.000000
# 25%          11.000000
# 50%          23.000000
# 75%          47.000000
# max         559.000000
# Name: 0, dtype: float64

# %%
df_pc = pd.read_csv("/kaggle/input/mind-label-seq-gen/framelabel_clicks.txt", header=None)
df_pc[0].str.split().map(len).describe()
# Out:
# count    231530.000000
# mean         41.038518
# std          48.911021
# min           2.000000
# 25%          11.000000
# 50%          25.000000
# 75%          52.000000
# max         559.000000
# Name: 0, dtype: float64
